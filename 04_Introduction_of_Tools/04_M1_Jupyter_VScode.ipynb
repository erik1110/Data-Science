# %% [markdown]
#  ## Jupyter Lab

# %% [markdown]
# Jupyter 還有一個更方便的產品，而我認為這是更好上手，推薦給大家使用！

# %% [markdown]
# ### 安裝

# %% [markdown]
# 只要直接利用 pip install 就可以安裝
# ```
# pip install jupyterlab
#
# ```
# 接著在命令提示字元打即可打開
# ```
# jupyter lab
# ```
# ![image.png](attachment:ea9fa44d-9778-4afe-a8ab-cf8507d47c52.png)

# %% [markdown]
# ### 功能面板
#
# 對應下圖藍色圓圈處，分別介紹：
#
# 1. 新增物件：點擊後右邊會出現各式各樣的圖示，方便使用者隨時新增操作
#
# 2. 新增資料夾
#
# 3. 上傳檔案
#
# 4. 重新整理
#
# 5. 新增一個 notebook
#
# 6. 新增一個 terminal

# %% [markdown]
# ![image.png](attachment:a686dc64-db8d-4294-b184-179bd229e661.png)

# %% [markdown]
# ### 撰寫程式碼
#
# 操作與 jupyter 類似，亦可以使用快捷鍵等等
#
# 1. 存檔
# 2. 新增一個窗格
# 3. 刪除一個窗格
# 4. 複製
# 5. 貼上
# 6. 執行程式碼
# 7. 停止程式碼
# 8. Restart Kernel
# 9. Restart Kernel
# 10. 選擇窗格的編輯功能(Code、Markdown...)

# %% [markdown]
# ![image.png](attachment:b23a5643-c5d0-4cf6-b62b-1df3bfc5a295.png)

# %% [markdown]
# ### 檔案操作
#
# ![image.png](attachment:589ed967-0588-4e1c-b2e1-e93be4605d69.png)

# %% [markdown]
# ### Kernel 操作
#
# ![image.png](attachment:d3e7112a-2d27-4650-8683-333bc259c408.png)

# %% [markdown]
# ### 終端機基本指令操作
#
# | 指令 | 說明 | 範例 |
# | -------- | -------- | -------- |
# | cd   | 切換目錄     |   ``` cd 目錄 ```     |
# | cd   | 切換上一層     |   ``` cd .. ```     |
# | tab   | 系統提示該指令  |   (需搭配其他指令，例如 cd 搭配 tab 可以直接看到可以切換目錄)  ``` cd (按tab) ```    |
# | ls   | 列出目錄有的檔案 |  -l 顯示完成檔案權限(可不加) -a 顯示.開頭的檔案(可不加) ``` ls -al ```     |
# | mkdir   | 建立一個資料夾 |   ``` mkdir 資料夾名稱 ```     |
# | cp   | 複製檔案或資料夾 | -r 代表是資料夾操作(可不加)  ``` cp -r 原檔案或資料夾路徑 新檔案或資料夾路徑```     |
# | rm   | 刪除檔案或資料夾 | -r 代表是資料夾操作(可不加)  ``` rm -r 檔案或資料夾路徑```     |
# | pwd   | 顯示目前路徑 | ``` pwd ```     |
# | crtl+c   | 強制停止目前指令執行 |   |

# %% [markdown]
#  ## Visual Studio Code

# %% [markdown]
# ### 安裝

# %% [markdown]
# 請至連結下載對應版本，[下載連結](https://code.visualstudio.com/)

# %% [markdown]
# ![image.png](attachment:499343bf-2491-472f-b9c2-bccf458eecdf.png)

# %% [markdown]
# ### 擴充功能
#
# 請安裝 python
#
# ![image.png](attachment:ed2c1715-4f93-455f-84e1-5fd5c1a8db3e.png)

# %% [markdown]
# ### 功能面板
# ![image.png](attachment:beffd7f5-03c6-4edc-83f9-3aee4460d632.png)
